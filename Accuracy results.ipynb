# %%
import matplotlib.pyplot as plt
from math import fabs
import pandas as pd
from sklearn.metrics import f1_score,accuracy_score, mean_squared_error, mean_squared_log_error
import numpy as np

# %%
n_groups = 4

# %%
accuracy = (97.07, 92.39, 96.49,97.66)

# %%
fig, ax = plt.subplots(figsize=(9,6))
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

# %%
rects1 = plt.bar(index, accuracy, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Accuracy')
plt.xlabel('Parameters')
plt.ylabel('Percentage')
plt.title('Performance Graph')
plt.xticks(index + bar_width, ('Logistic Regression', 'Decision tree ', 'Random classifier','Supervector classifier'))
plt.legend(loc = 'upper right')
 
plt.tight_layout()
plt.show()
